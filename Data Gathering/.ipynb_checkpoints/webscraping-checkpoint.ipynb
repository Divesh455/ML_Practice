# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text

# %%
soup = BeautifulSoup(webpage)

# %%
# print(soup.prettify())

# %%
# soup.find_all('h1')[0].text

# %%
company = soup.find_all('div', class_='companyCardWrapper')

# %%
len(company)
# Out:
# 20

# %%
company_name = []
company_rating = []
company_review = []
avg_sal = []
services = []
locations = []
for i in company:
    name = i.find('h2', class_='companyCardWrapper__companyName').text.strip()
    company_name.append(name)

    rating = i.find("div", class_="rating_text rating_text--md")
    company_rating.append(rating.get_text(strip=True))

    review = i.find_all('span', class_='companyCardWrapper__ActionCount')[0]
    company_review.append(review.text)

    sal = i.find_all('span',class_='companyCardWrapper__ActionCount')[1].text
    avg_sal.append(sal)

    sevices = i.find('span',class_='companyCardWrapper__interLinking').text.strip().split('|')[0]
    services.append(sevices)

    location = i.find('span',class_='companyCardWrapper__interLinking').text.strip().split('|')[1].split('+')[0].split(' /')[0]
    locations.append(location)

# %%
print(company_name)
print(company_rating)
print(company_review)
print(avg_sal)
print(services)
print(locations)
# Out:
# ['TCS', 'Accenture', 'Wipro', 'Cognizant', 'Capgemini', 'HDFC Bank', 'Infosys', 'ICICI Bank', 'HCLTech', 'Tech Mahindra', 'Genpact', 'Teleperformance', 'Jio', 'Axis Bank', 'Concentrix Corporation', 'Amazon', 'iEnergizer', 'Reliance Retail', 'LTIMindtree', 'IBM']
# ['3.3', '3.7', '3.6', '3.6', '3.7', '3.8', '3.5', '4.0', '3.4', '3.4', '3.6', '3.8', '4.4', '3.6', '3.6', '3.9', '4.6', '3.9', '3.6', '3.9']
# ['1.1L', '71.4k', '63.5k', '59.8k', '51.5k', '50.7k', '47.3k', '45k', '44.5k', '42.4k', '40.9k', '36.7k', '32.6k', '32.4k', '31.4k', '30.8k', '27.1k', '27k', '25.8k', '25.3k']
# ['9.8L', '6.5L', '4.8L', '6L', '4.8L', '1.5L', '5.2L', '1.5L', '3.8L', '2.8L', '2.3L', '96.4k', '62.1k', '1L', '1.3L', '1.5L', '24.1k', '76.4k', '1.9L', '2.1L']
# ['IT Services & Consulting ', 'IT Services & Consulting ', 'IT Services & Consulting ', 'IT Services & Consulting ', 'IT Services & Consulting ', 'Banking ', 'IT Services & Consulting ', 'Banking ', 'IT Services & Consulting ', 'IT Services & Consulting ', 'IT Services & Consulting ', 'BPO ', 'Telecom ', 'Banking ', 'BPO ', 'Internet ', 'BPO ', 'Retail ', 'IT Services & Consulting ', 'IT Services & Consulting ']
# [' Bangalore', ' Bangalore', ' Hyderabad', ' Hyderabad', ' Bangalore', ' Mumbai ', ' Bangalore', ' Mumbai ', ' Chennai ', ' Hyderabad', ' Hyderabad', ' Mumbai ', ' Mumbai ', ' Mumbai ', ' Bangalore', ' Bangalore', ' Noida ', ' Mumbai ', ' Bangalore', ' Bangalore']

# %%
lower_name = []

for i in company_name:
    lower = i.lower()
    lower_name.append(lower)

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
about_company = []
for i in lower_name:
    about_webpage = requests.get(f'https://www.ambitionbox.com/overview/{i}-overview',headers=headers).text
    new_soup = BeautifulSoup(about_webpage)
    about = new_soup.find('div',class_='text-sm font-pn-400 [&_ul]:list-disc [&_ol]:list-[auto] [&_ul]:ml-5 [&_ol]:ml-5').text
    about_company.append(about)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 6
#       4 about_webpage = requests.get(f'https://www.ambitionbox.com/overview/{i}-overview',headers=headers).text
#       5 new_soup = BeautifulSoup(about_webpage)
# ----> 6 about = new_soup.find('div',class_='text-sm font-pn-400 [&_ul]:list-disc [&_ol]:list-[auto] [&_ul]:ml-5 [&_ol]:ml-5').text
#       7 about_company.append(about)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(about_

# %%
# Out:
# 'Tata Consultancy Services is an IT services, consulting and business solutions organization that has been partnering with many of the world’s largest businesses for the past 50 years. We believe innovation and collective knowledge can transform all our futures with greater purpose.'
