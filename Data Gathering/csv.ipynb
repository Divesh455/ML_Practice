# %%
import pandas as pd

# %%
# !pip install pandas

# %% [markdown]
# # opening csv file by giving name

# %%
df = pd.read_csv('aug_train.csv')

# %%
df
# Out:
#          Sales Rep      Sales Rep Id                 Company Name  \
# 0       Deann Hall  61KSIDWP42XZSL8X      Money-Hungry Commissary
# 1       Deann Hall  61KSIDWP42XZSL8X      Underdeveloped Sympathy
# 2       Deann Hall  61KSIDWP42XZSL8X             Orderly Fighting
# 3       Deann Hall  61KSIDWP42XZSL8X  Synchronous Oxytetracycline
# 4       Deann Hall  61KSIDWP42XZSL8X         Panicky Methacrylate
# ...            ...               ...                          ...
# 4804  Marie Binion  9ALNM4NDWJXNBKE5                   Lucky Lads
# 4805  Marie Binion  9ALNM4NDWJXNBKE5          Fee-Per-Case Belief
# 4806  Marie Binion  9ALNM4NDWJXNBKE5     Peridontal Storyteller'S
# 4807  Marie Binion  9ALNM4NDWJXNBKE5     Postgraduate Top-Quality
# 4808  Marie Binion  9ALNM4NDWJXNBKE5             37Th Schoolbooks
#
#             Company Id
# 0     LN4OZ8T4VIVQBXLR
# 1     B7B9TXC4QP6OPK6D
# 2     6MHS0OL2UUVR0MV5
# 3     910PYRYKOX1BOHWG
# 4     IVDNKFYFYA75GDAR
# ...                ...
# ...

# %% [markdown]
# # opening csv file from an URL

# %%
import requests
from io import StringIO

# %%
url = 'https://raw.githubusercontent.com/FBosler/Medium-Data-Extraction/master/sales_team.csv' # Example URL
df = pd.read_csv(url)

# Display the first 5 rows of the data frame
print(df.head())
# Out:
#     Sales Rep      Sales Rep Id                 Company Name        Company Id
# 0  Deann Hall  61KSIDWP42XZSL8X      Money-Hungry Commissary  LN4OZ8T4VIVQBXLR
# 1  Deann Hall  61KSIDWP42XZSL8X      Underdeveloped Sympathy  B7B9TXC4QP6OPK6D
# 2  Deann Hall  61KSIDWP42XZSL8X             Orderly Fighting  6MHS0OL2UUVR0MV5
# 3  Deann Hall  61KSIDWP42XZSL8X  Synchronous Oxytetracycline  910PYRYKOX1BOHWG
# 4  Deann Hall  61KSIDWP42XZSL8X         Panicky Methacrylate  IVDNKFYFYA75GDAR
